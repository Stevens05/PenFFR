# %% [markdown]
# # RF for LIVE_NFLX QoE Prediction

# %% [markdown]
# ## Load the useful librairies

# %%
# Load the libraries
from os import listdir
from os.path import isfile, join
import sys
from pathlib import Path
import numpy as np
import random as rd
import pandas as pd
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings("ignore")
import pickle
import scipy.io
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Load and transform the "mat.files"  data

# %%
root_folder =  "Mat_Files"
mat_files = [f for f in listdir(root_folder) if "mat" in f and isfile(join(root_folder, f))]
mat_files
# Out:
# ['Chimera1102347_VMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'AirShow_VMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'MeridianConversation_OracleVMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'Sparks_HuangBufferBasedAdaptor_Trace_5.mat',
#  'Soccer_HuangBufferBasedAdaptor_Trace_4.mat',
#  'CosmosLaundromat_HuangBufferBasedAdaptor_Trace_6.mat',
#  'Sparks_OracleVMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'GTA_OracleVMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'ElFuenteDance_SimpleThroughputBasedAdaptor_Trace_3.mat',
#  'AirShow_HuangBufferBasedAdaptor_Trace_5.mat',
#  'Chimera1102347_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'Soccer_HuangBufferBasedAdaptor_Trace_3.mat',
#  'TearsOfSteelStatic_OracleVMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'ElFuenteDance_SimpleThroughputBasedAdaptor_Trace_0.mat',
#  'Chimera1102353_VMAFViterbiQualityBasedAdaptor_Trace_1.mat',
#  'TearsOfSteelStatic_VMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'GTA_HuangBufferBasedAdaptor_Trace_5.mat',
#  'ElFuenteMask_VMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'Soccer_OracleVMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'CosmosLaundromat_VMAFViterbiQualityBasedAdaptor_Trace_1.mat',
#  'CosmosLaundromat_OracleVMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'ElFuenteMask_SimpleThroughputBasedAdaptor_Trace_6.mat',
#  'AsianFusion_VMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'TearsOfSteelStatic_HuangBufferBasedAdaptor_Trace_2.mat',
#  'Skateboarding_HuangBufferBasedAdaptor_Trace_2.mat',
#  'AsianFusion_SimpleThroughputBasedAdaptor_Trace_2.mat',
#  'CosmosLaundromat_HuangBufferBasedAdaptor_Trace_2.mat',
#  'Chimera1102347_SimpleThroughputBasedAdaptor_Trace_1.mat',
#  'MeridianDriving_SimpleThroughputBasedAdaptor_Trace_3.mat',
#  'Soccer_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'AirShow_HuangBufferBasedAdaptor_Trace_4.mat',
#  'ElFuenteDance_VMAFViterbiQualityBasedAdaptor_Trace_1.mat',
#  'Skateboarding_OracleVMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'AirShow_SimpleThroughputBasedAdaptor_Trace_3.mat',
#  'Sparks_OracleVMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'Skateboarding_OracleVMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'Skateboarding_VMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'CosmosLaundromat_SimpleThroughputBasedAdaptor_Trace_3.mat',
#  'AsianFusion_SimpleThroughputBasedAdaptor_Trace_0.mat',
#  'TearsOfSteelStatic_OracleVMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'Chimera1102353_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'Skateboarding_VMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'MeridianConversation_HuangBufferBasedAdaptor_Trace_0.mat',
#  'Soccer_SimpleThroughputBasedAdaptor_Trace_2.mat',
#  'CosmosLaundromat_VMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'ElFuenteMask_OracleVMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'AirShow_HuangBufferBasedAdaptor_Trace_3.mat',
#  'AirShow_SimpleThroughputBasedAdaptor_Trace_6.mat',
#  'Chimera1102347_SimpleThroughputBasedAdaptor_Trace_6.mat',
#  'MeridianConversation_SimpleThroughputBasedAdaptor_Trace_5.mat',
#  'TearsOfSteelRobot_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'ElFuenteDance_VMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'AirShow_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'TearsOfSteelStatic_SimpleThroughputBasedAdaptor_Trace_6.mat',
#  'GTA_VMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'MeridianDriving_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'AsianFusion_HuangBufferBasedAdaptor_Trace_1.mat',
#  'TearsOfSteelStatic_VMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'TearsOfSteelRobot_HuangBufferBasedAdaptor_Trace_1.mat',
#  'AsianFusion_VMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'AsianFusion_SimpleThroughputBasedAdaptor_Trace_4.mat',
#  'TearsOfSteelRobot_OracleVMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'MeridianDriving_VMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'CosmosLaundromat_VMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'Chimera1102353_VMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'ElFuenteMask_VMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'Chimera1102347_OracleVMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'Soccer_OracleVMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'TearsOfSteelStatic_SimpleThroughputBasedAdaptor_Trace_3.mat',
#  'Sparks_SimpleThroughputBasedAdaptor_Trace_4.mat',
#  'Chimera1102353_OracleVMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'Chimera1102353_HuangBufferBasedAdaptor_Trace_1.mat',
#  'MeridianConversation_OracleVMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'Chimera1102353_VMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'GTA_VMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'AirShow_SimpleThroughputBasedAdaptor_Trace_4.mat',
#  'Sparks_VMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'Soccer_OracleVMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'CosmosLaundromat_SimpleThroughputBasedAdaptor_Trace_5.mat',
#  'MeridianConversation_HuangBufferBasedAdaptor_Trace_3.mat',
#  'Sparks_VMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'AsianFusion_SimpleThroughputBasedAdaptor_Trace_1.mat',
#  'AirShow_VMAFViterbiQualityBasedAdaptor_Trace_1.mat',
#  'ElFuenteMask_SimpleThroughputBasedAdaptor_Trace_2.mat',
#  'GTA_VMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'CosmosLaundromat_HuangBufferBasedAdaptor_Trace_1.mat',
#  'AirShow_HuangBufferBasedAdaptor_Trace_6.mat',
#  'ElFuenteMask_SimpleThroughputBasedAdaptor_Trace_4.mat',
#  'MeridianConversation_VMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'CosmosLaundromat_OracleVMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'Chimera1102353_SimpleThroughputBasedAdaptor_Trace_6.mat',
#  'GTA_VMAFViterbiQualityBasedAdaptor_Trace_1.mat',
#  
VMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'MeridianConversation_HuangBufferBasedAdaptor_Trace_6.mat',
#  'MeridianConversation_OracleVMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'ElFuenteDance_VMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'ElFuenteDance_HuangBufferBasedAdaptor_Trace_6.mat',
#  'Skateboarding_OracleVMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'Chimera1102347_VMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'CosmosLaundromat_HuangBufferBasedAdaptor_Trace_5.mat',
#  'MeridianConversation_HuangBufferBasedAdaptor_Trace_2.mat',
#  'ElFuenteMask_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'AirShow_SimpleThroughputBasedAdaptor_Trace_1.mat',
#  'GTA_SimpleThroughputBasedAdaptor_Trace_5.mat',
#  'ElFuenteDance_HuangBufferBasedAdaptor_Trace_2.mat',
#  'TearsOfSteelStatic_SimpleThroughputBasedAdaptor_Trace_1.mat',
#  'TearsOfSteelRobot_OracleVMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'GTA_HuangBufferBasedAdaptor_Trace_1.mat',
#  'GTA_SimpleThroughputBasedAdaptor_Trace_4.mat',
#  'AsianFusion_OracleVMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'ElFuenteDance_SimpleThroughputBasedAdaptor_Trace_6.mat',
#  'TearsOfSteelRobot_OracleVMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'ElFuenteDance_VMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'Skateboarding_VMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'ElFuenteMask_SimpleThroughputBasedAdaptor_Trace_0.mat',
#  'MeridianConversation_VMAFViterbiQualityBasedAdaptor_Trace_4.mat',
#  'ElFuenteDance_HuangBufferBasedAdaptor_Trace_0.mat',
#  'Skateboarding_HuangBufferBasedAdaptor_Trace_1.mat',
#  'AsianFusion_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'MeridianDriving_OracleVMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'TearsOfSteelRobot_VMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'Skateboarding_OracleVMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'Soccer_HuangBufferBasedAdaptor_Trace_0.mat',
#  'TearsOfSteelRobot_VMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'Sparks_OracleVMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'MeridianDriving_HuangBufferBasedAdaptor_Trace_0.mat',
#  'TearsOfSteelRobot_VMAFViterbiQualityBasedAdaptor_Trace_2.mat',
#  'MeridianDriving_HuangBufferBasedAdaptor_Trace_3.mat',
#  'AirShow_VMAFViterbiQualityBasedAdaptor_Trace_3.mat',
#  'CosmosLaundromat_VMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'MeridianConversation_SimpleThroughputBasedAdaptor_Trace_6.mat',
#  'MeridianDriving_OracleVMAFViterbiQualityBasedAdaptor_Trace_1.mat',
#  'GTA_VMAFViterbiQualityBasedAdaptor_Trace_5.mat',
#  'TearsOfSteelStatic_HuangBufferBasedAdaptor_Trace_4.mat',
#  'Soccer_HuangBufferBasedAdaptor_Trace_2.mat',
#  'TearsOfSteelStatic_OracleVMAFViterbiQualityBasedAdaptor_Trace_1.mat',
#  'AirShow_VMAFViterbiQualityBasedAdaptor_Trace_0.mat',
#  'MeridianDriving_OracleVMAFViterbiQualityBasedAdaptor_Trace_6.mat',
#  'CosmosLaundromat_SimpleThroughputBasedAdaptor_Trace_1.mat',
#  'ElFuenteMask_VMAFViterbiQualityBasedAdaptor_Trace_2.mat']

# %%
name_vars = list(scipy.io.loadmat(root_folder + "/" + mat_files[0]).keys())[4:39]
data = {}
for var in name_vars:
    print(var)
    data[var] = pd.DataFrame()
    for f in mat_files:
        mat = scipy.io.loadmat(root_folder + "/" + f)
        tmp_var = pd.DataFrame(mat[var])
        data[var] = pd.concat([data[var], tmp_var])
# Out:
# STRRED
# N_playback_frames
# VMAF
# SSIM
# buffer_evolution_sec
# height
# playback_duration_sec
# playout_bitrate
# continuous_zscored_mos
# scene_cuts_detected
# PSNR
# MSSIM
# per_segment_encoding_QP
# rebuffer_duration_sec
# video_duration_sec
# width
# per_segment_encoding_height
# selected_streams
# distorted_mp4_video
# adaptation_algorithm
# rebuffer_number
# content_spatial_information
# content_temporal_information
# frame_rate
# per_segment_encoding_width
# cropping_parameters
# throughput_trace_name
# content_name_acronym
# scene_cuts
# N_rebuffer_frames
# is_rebuffered_bool
# throughput_trace_kbps
# reference_yuv_video
# N_total_frames
# retrospective_zscored_mos

# %%
scal_vars = ["playback_duration_sec", "rebuffer_duration_sec", "video_duration_sec", "N_playback_frames", "height", "width",
             "rebuffer_number", "content_spatial_information", "content_temporal_information", "frame_rate",
             "N_rebuffer_frames", "N_total_frames", "throughput_trace_name"]
X_scal = pd.DataFrame()
for var in scal_vars:
    tmp_var = data[var]
    X_scal = pd.concat([X_scal, tmp_var], axis = 1)
    
X_scal.columns = scal_vars
X_scal.to_csv("data/scal_vars.csv")
X_scal
# Out:
#     playback_duration_sec  rebuffer_duration_sec  video_duration_sec  \
# 0               27.533333               0.033333           27.566667
# 0               27.133333               4.300000           31.433333
# 0               26.633333               0.000000           26.633333
# 0               27.933333               0.000000           27.933333
# 0               25.000000               4.320000           29.320000
# ..                    ...                    ...                 ...
# 0               26.625000               0.000000           26.625000
# 0               27.133333               0.000000           27.133333
# 0               27.000000               0.000000           27.000000
# 0               27.000000               0.000000           27.000000
# 0               27.694333               0.000000           27.694333
#
#     N_playback_frames  height  width  rebuffer_number  \
# 0                 826    1080   1920                1
# 0                 814    1080   1920                3
# 0                 799    1080   1920                0
# 0                 838    1080   1920                0
# 0                 625    1080   1920                3
# ..                ...     ...    ...              ...
# 0                 639    1080   1920                0
# 0                 814    1080   1920                0
# 0                 810    1080   1920                0
# 0                 648    1080   1920                0
# 0                 664    1080   1920                0
#
#     content_spatial_information  content_temporal_information  frame_rate  \
# 0                     46.559426                      6.704285   30.000000
# 0                     24.465410                      9.669711   30.000000
# 0                     36.516497                      3.111322   30.000000
# 0                     51.239882                     12.835748   30.000000
# 0                     92.946820                     30.131946   25.000000
# ..                          ...                           ...         ...
# 0                     43.562215                     11.106232   24.000000
# 0                     24.465410                      9.669711   30.000000
# 0                     45.257302                      6.470532   30.000000
# 0                     34.617578                     21.403401   24.000000
# 0                     72.459268                     30.948106   23.976024
#
#     N_rebuffer_frames  N_total_frames       throughput_trace_name
# 0                   1             827           Train_vestby_oslo
# 0                 129             943        Bus_ljansbakken_oslo
# 0                   0             799           Train_vestby_oslo
# 0                   0             838     Ferry_nesoddtangen_oslo
# 0                 108             733        Bus_ljansbakken_oslo
# ..                ...             ...                         ...
# 0                   0             639  Tram_jernbanetorget_ljabru
# 0                   0             814         Car_snaroya_smestad
# 0                   0             810  Tram_ljabru_jernbanetorget
# 0                   0             648  Tram_jernbanetorget_ljabru
# 0                   0             664           Train_vestby_oslo
#
# [420 rows x 13 columns]

# %%
cont_vars = ["buffer_evolution_sec", "MSSIM", "per_segment_encoding_height", "per_segment_encoding_QP", "playout_bitrate",
             "PSNR", "scene_cuts", "selected_streams", "SSIM", "STRRED", "throughput_trace_kbps", "VMAF",
             "per_segment_encoding_width", "scene_cuts", "scene_cuts_detected", "continuous_zscored_mos", "is_rebuffered_bool"]
for var in cont_vars:
    tmp = data[var]
    tmp.to_csv("data/" + var + ".csv")

# %%
#root_folder = "/QoE_Data/LIVE_NFLX/data/"
root_folder = "data/"
csv_files = [f for f in listdir(root_folder) if "csv" in f and isfile(join(root_folder, f))]
csv_files
# Out:
# ['per_segment_encoding_height.csv',
#  'scene_cuts.csv',
#  'is_rebuffered_bool.csv',
#  'VMAF.csv',
#  'continuous_zscored_mos.csv',
#  'selected_streams.csv',
#  'PSNR.csv',
#  'SSIM.csv',
#  'scene_cuts_detected.csv',
#  'scal_vars.csv',
#  'per_segment_encoding_QP.csv',
#  'playout_bitrate.csv',
#  'buffer_evolution_sec.csv',
#  'throughput_trace_kbps.csv',
#  'MSSIM.csv',
#  'per_segment_encoding_width.csv',
#  'STRRED.csv']

# %%
# Build the dataframe of features statistics
df_new = pd.DataFrame()
for f in csv_files:
    if 'continuous' in f:# or 'scal_vars' in f:
        continue
    if 'scal_vars' in f:
        print(f)
        tmp_data = pd.read_csv(root_folder + f).iloc[: , 1:]
        df_new["test_var"] = tmp_data["throughput_trace_name"]
        ["Train_vestby_oslo","Tram_jernbanetorget_ljabru"]
    else:
        print(f)
        tmp_data = pd.read_csv(root_folder + f).iloc[: , 1:]
        df_new[f+"_min"] = tmp_data.min(axis=1)
        df_new[f+"_max"] = tmp_data.max(axis=1)
        df_new[f+"_sum"] = tmp_data.sum(axis=1)
        df_new[f+"_mean"] = tmp_data.mean(axis=1)
        df_new[f+"_median"] = tmp_data.median(axis=1)
        df_new[f+"_std"] = tmp_data.std(axis=1)
        df_new[f+"_1stQ"] = tmp_data.quantile(0.25, axis=1)
        df_new[f+"_3rdQ"] = tmp_data.quantile(0.75, axis=1)
        df_new[f+"_skew"] = tmp_data.skew(axis=1)
        df_new[f+"_kur"] = tmp_data.kurtosis(axis=1)
        df_new[f+"_count"] = tmp_data.shape[1] - tmp_data.isnull().sum(axis=1)
    
df_new.head(10)
# Out:
# per_segment_encoding_height.csv
# scene_cuts.csv
# is_rebuffered_bool.csv
# VMAF.csv
# selected_streams.csv
# PSNR.csv
# SSIM.csv
# scene_cuts_detected.csv
# scal_vars.csv
# per_segment_encoding_QP.csv
# playout_bitrate.csv
# buffer_evolution_sec.csv
# throughput_trace_kbps.csv
# MSSIM.csv
# per_segment_encoding_width.csv
# STRRED.csv
#    per_segment_encoding_height.csv_min  per_segment_encoding_height.csv_max  \
# 0                                360.0                               1080.0
# 1                                360.0                                720.0
# 2                                720.0                               1080.0
# 3                                360.0                               1080.0
# 4                                216.0                                720.0
# 5                                270.0                                720.0
# 6                                360.0                               1080.0
# 7                                360.0                                720.0
# 8                                360.0                                720.0
# 9                                360.0                               1080.0
#
#    per_segment_encoding_height.csv_sum  per_segment_encoding_height.csv_mean  \
# 0                              10440.0                            652.500000
# 1                               8100.0                            540.000000
# 2                              15480.0                            967.500000
# 3                              13140.0                            821.250000
# 4                               5346.0                            381.857143
# 5                               5580.0                            372.000000
# 6                              13500.0                            843.750000
# 7                               7200.0                            480.000000
# 8                               6480.0                            432.000000
# 9                              13140.0                            876.000000
#
#    per_segment_encoding_height.csv_median  \
# 0                                   720.0
# 1                                   540.0
# 2                                  1080.0
# 3                                   900.0
# 4                                   360.0
# 5                                   360.0
# 6                                   720.0
# 7                                   540.0
# 8                                   360.0
# 9                                  1080.0
#
#    per_segment_encoding_height.csv_std  per_segment_encoding_height.csv_1stQ  \
# 0                           226.495033                                 495.0
# 1                           180.000000                                 360.0
# 2                           172.336879                                 720.0
# 3                           286.260371                                 540.0
# 4                           119.017683                                 360.0
# 5                           101.291658                                 360.0
# 6                           234.403498                                 720.0
# 7                           111.098412                                 360.0
# 8                           132.621912                                 360.0
# 9                           310.777826                                 630.0
#
#    per_segment_encoding_height.csv_3rdQ  per_segment_encoding_height.csv_skew  \
# 0                                 720.0                              0.365690
# 1                                 720.0                              0.000000
# 2                                1080.0                             -0.895257
# 3                                1080.0                             -0.414217
# 4                                 360.0                              1.945719
# 5                                 360.0                              3.172270
# 6                                1080.0                             -0.367916
# 7                                 540.0                              0.311574
# 8                                 450.0                              1.631987
# 9                                1080.0                             -1.013194
#
#    per_segment_encoding_height.csv_kur  ...  STRRED.csv_max  STRRED.csv_sum  \
# 0                            -0.052893  ...      345.080129    46296.463832
# 1                            -2.230769  ...      178.020214    29553.196034
# 2                            -1.390609  ...       53.046983     6740.454856
# 3                            -1.550333  ...      414.646534    84706.630824
# 4                             5.072595  ...     4988.706087   413306.944583
# 5                            11.767222  ...     1580.726527   239969.119295
# 6                            -0.846684  ...      486.525293    74952.459676
# 7                            -0.403846  ...     2878.433902   346804.384511
# 8                             1.320051  ...      980.669771   104405.634254
# 9                            -0.902676  ...      178.020214    15246.744923
#
#    STRRED.csv_mean  STRRED.csv_median  STRRED.csv_std  STRRED.csv_1stQ  \
# 0        56.048988          20.606288       67.807192        13.473389
# 1        36.306138          27.051776       31.392378        10.311113
# 2         8.436114           5.372933        7.735403         3.494339
# 3       101.081898          87.856483       88.527189        18.707355
# 4       661.291111         316.528598     1052.775797       238.017406
# 5       370.322715         250.774885      313.244878       140.508243
# 6        89.442076          52.678424       88.080972        18.951725
# 7       443.483868         162.795678      554.550252       107.391930
# 8       164.937811          95.961426      193.934569        53.768635
# 9        18.730645           3.900427       29.041117         2.056327
#
#    STRRED.csv_3rdQ  STRRED.csv_skew  STRRED.csv_kur  STRRED.csv_count
# 0        73.651502         1.553019        1.413226               826
# 1        56.005850         1.266429        1.636420               814
# 2         9.952786         2.195295        5.512179               799
# 3       144.089248         0.978122        0.345673               838
# 4       494.201721         3.041851        7.953462               625
# 5       514.103691         1.196269        0.552229               648
# 6       143.925879         1.375703        1.720191               838
# 7       464.951388         1.755489        2.270178               782
# 8       184.680747         2.425078        5.775314               633
# 9        24.158844         2.049725        4.524785               814
#
# [10 rows x 166 columns]

# %%
tmp_data = pd.read_csv(root_folder + 'scal_vars.csv').iloc[: , 1:13]
tmp_data
# Out:
#      playback_duration_sec  rebuffer_duration_sec  video_duration_sec  \
# 0                27.533333               0.033333           27.566667
# 1                27.133333               4.300000           31.433333
# 2                26.633333               0.000000           26.633333
# 3                27.933333               0.000000           27.933333
# 4                25.000000               4.320000           29.320000
# ..                     ...                    ...                 ...
# 415              26.625000               0.000000           26.625000
# 416              27.133333               0.000000           27.133333
# 417              27.000000               0.000000           27.000000
# 418              27.000000               0.000000           27.000000
# 419              27.694333               0.000000           27.694333
#
#      N_playback_frames  height  width  rebuffer_number  \
# 0                  826    1080   1920                1
# 1                  814    1080   1920                3
# 2                  799    1080   1920                0
# 3                  838    1080   1920                0
# 4                  625    1080   1920                3
# ..                 ...     ...    ...              ...
# 415                639    1080   1920                0
# 416                814    1080   1920                0
# 417                810    1080   1920                0
# 418                648    1080   1920                0
# 419                664    1080   1920                0
#
#      content_spatial_information  content_temporal_information  frame_rate  \
# 0                      46.559426                      6.704285   30.000000
# 1                      24.465410                      9.669711   30.000000
# 2                      36.516497                      3.111322   30.000000
# 3                      51.239882                     12.835748   30.000000
# 4                      92.946820                     30.131946   25.000000
# ..                           ...                           ...         ...
# 415                    43.562215                     11.106232   24.000000
# 416                    24.465410                      9.669711   30.000000
# 417                    45.257302                      6.470532   30.000000
# 418                    34.617578                     21.403401   24.000000
# 419                    72.459268                     30.948106   23.976024
#
#      N_rebuffer_frames  N_total_frames
# 0                    1             827
# 1                  129             943
# 2                    0             799
# 3                    0             838
# 4                  108             733
# ..                 ...             ...
# 415                  0             639
# 416                  0             814
# 417                  0             810
# 418                  0             648
# 419                  0             664
#
# [420 rows x 12 columns]

# %%
print(df_new.shape)
df_new = pd.concat([df_new, tmp_data], axis=1)
print(df_new.shape)
# Out:
# (420, 166)
# (420, 178)

# %%
# Build the response variable
MOS_df = pd.read_csv(root_folder + "continuous_zscored_mos.csv")
df_new["mean"] = MOS_df.mean(axis = 1)
df_new["std"] = MOS_df.std(axis = 1)
df_new.shape
# Out:
# (420, 180)

# %%
# count the effective number of MOS score per video (on test set)
fill_mos = pd.DataFrame([MOS_df.shape[1] - MOS_df.isnull().sum(axis=1)]).T
fill_mos["test_var"] = pd.read_csv(root_folder + "scal_vars.csv")["throughput_trace_name"]
fill_mos = np.array(fill_mos[fill_mos["test_var"].isin(["Train_vestby_oslo","Tram_jernbanetorget_ljabru"])][0])
fill_mos
# Out:
# array([ 828,  800,  783,  812,  649,  640,  798,  828,  649,  827,  634,
#         839,  798,  626,  643,  816,  649,  816,  649,  844,  816,  828,
#         675,  649,  783,  798,  816,  640,  652,  634,  825,  811,  839,
#         662,  839,  626,  634,  816,  665,  665,  665,  640,  645,  783,
#         640,  626,  800,  839,  816,  806,  665, 1005,  783,  839,  649,
#         649,  659,  798,  811,  811,  828,  783,  811,  652,  812,  800,
#         626,  808,  665,  783,  811,  812,  640,  626,  649,  626,  815,
#         838,  795,  665,  800,  649,  815,  828,  839,  795,  783,  815,
#         822,  643,  869,  795,  839,  649,  643,  815,  634,  812,  830,
#         827,  815,  812,  811,  800,  829,  626,  827,  812,  800,  815,
#         643,  640,  783,  795,  652,  811,  626,  640,  649,  665])

# %% [markdown]
# # Random Forest

# %%
# Train/Test split by throughput_trace_name
df_train = df_new[~df_new["test_var"].isin(["Train_vestby_oslo","Tram_jernbanetorget_ljabru"])]
X_train = df_train.drop(["mean", "std", "test_var"], axis = 1) 
y_train = df_train["mean"]
y_train2 = df_train["std"]

# %%
X_train.shape
# Out:
# (300, 177)

# %%
df_test = df_new[df_new["test_var"].isin(["Train_vestby_oslo","Tram_jernbanetorget_ljabru"])]
X_test = df_test.drop(["mean", "std", "test_var"], axis = 1) 
y_test = df_test["mean"]
y_test2 = df_test["std"]

# %%
X_test.shape
# Out:
# (120, 177)

# %%
########################################
# Feature Importance
"""
Function to Fit model based on optimal values of depth and number of estimators and use it
to compute feature importance for all the features.
"""
def get_feature_importance(depth, n_tree, max_leaf, X_train, y_train):
    from sklearn.ensemble import RandomForestRegressor
    rf_opt = RandomForestRegressor(max_depth = depth, n_estimators = n_tree, max_leaf_nodes=max_leaf,
                                   random_state=42, bootstrap=False)
    rf_opt.fit(X_train, y_train)
    feature_importance = pd.DataFrame(rf_opt.feature_importances_)
    feature_importance.index = X_train.columns
    feature_importance = feature_importance.sort_values(by=list(feature_importance.columns),axis=0,ascending=False)

    return feature_importance

# Fewest features
"""
Function to Fit model based on optimal values of depth and number of estimators and feature importance
to find the fewest possible features to exceed the previously attained score with all selected features
"""
def get_fewest_features(depth, n_tree, max_leaf, importance):
    sorted_feature_names = importance.index
    # print('sorted_feature_names: ', sorted_feature_names)
    features = []
    for f in range(1,len(sorted_feature_names)+1):
        features.append(sorted_feature_names[0:f])
        # print('features:', features)
    return features

def get_scores(depth, n_tree, feats, max_leaf, X_train, y_train, X_test, y_test):
    from sklearn.ensemble import RandomForestRegressor
    model = RandomForestRegressor(max_depth=depth, n_estimators = n_tree, max_leaf_nodes=max_leaf, n_jobs=4,
                                   random_state=42, bootstrap=False)

    model.fit(X_train[feats], y_train)
    y_pred = model.predict(X_test[feats])
    
    accurac = model.score(X_test[feats], y_test)

    return accurac

# %%
def analyze_models(depths, n_trees, X_train, y_train, X_test, y_test, max_leaf, res_file):
    
    with open(res_file, "w") as res_file:
        print('depth;tree;n_feat;Accuracy;feats', file=res_file)
        for depth in depths:
            print(depth)
            for n_tree in n_trees:
                # get feature orders to use
                importance = get_feature_importance(depth, n_tree, max_leaf, X_train, y_train)
                m_feats = get_fewest_features(depth, n_tree, max_leaf, importance)
                accuracs = []
                for feats in m_feats:
                    # Get the scores with the given (depth, n_tree, feat)
                    accuracs = get_scores(depth, n_tree, feats, max_leaf, X_train, y_train, X_test, y_test)
                    print(str(depth)+';'+str(n_tree)+';'+str(len(feats))+';'+str(accuracs)+';'+str(list(feats)), file=res_file)
    print("Analysis Complete. Check output file.")
    return []

# %%
results_file = "Models_featImp.csv"
analyze_models(range(3,10,1), range(1,4,1), X_train, y_train, X_test, y_test, 500, results_file)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Analysis Complete. Check output file.
# []

# %%
results = pd.read_csv(results_file,sep=';')
results = results.sort_values(by=['Accuracy'], ascending=False)
print(results.head(10))
print("******")
# Out:
#       depth  tree  n_feat  Accuracy  \
# 3380      9     2      18  0.364035
# 2849      8     2      18  0.331218
# 3200      9     1      15  0.329749
# 3202      9     1      17  0.323816
# 3029      8     3      21  0.318080
# 3205      9     1      20  0.317421
# 2671      8     1      17  0.317369
# 1257      5     2      19  0.316324
# 3561      9     3      22  0.315136
# 1608      6     1      16  0.313715
#
#                                                   feats
# 3380  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 2849  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 3200  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 3202  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 3029  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 3205  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 2671  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 1257  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 3561  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# 1608  ['playout_bitrate.csv_3rdQ', 'STRRED.csv_1stQ'...
# ******

# %%
from sklearn.ensemble import RandomForestRegressor
importance = get_feature_importance(depth = 9, n_tree = 2, max_leaf = 500, X_train = X_train, y_train = y_train)
feats = get_fewest_features(9, 2, 500, importance)[16]
model = RandomForestRegressor(max_depth=9, n_estimators = 2, max_leaf_nodes=500, n_jobs=4,
                                   random_state=42, bootstrap=False)
model.fit(X_train[feats], y_train)
y_pred = model.predict(X_test[feats])

# %%
# RMSE
np.sqrt(np.mean((y_test - y_pred) ** 2))
# Out:
# 0.41663267447337926

# %%
results_file2 = "Models2_featImp.csv"
analyze_models(range(3,10,1), range(1,5,1), X_train, y_train2, X_test, y_test2, 500, results_file2)
# Out:
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# Analysis Complete. Check output file.
# []

# %%
results2 = pd.read_csv(results_file2,sep=';')
results2 = results2.sort_values(by=['Accuracy'], ascending=False)
print(results2.head(10))
print("******")
# Out:
#       depth  tree  n_feat  Accuracy  \
# 4256      9     1       9  0.200174
# 3547      8     1       8  0.040385
# 4257      9     1      10  0.027502
# 2839      7     1       8  0.008026
# 3364      7     4       2  0.003343
# 2833      7     1       2  0.003343
# 3187      7     3       2  0.003343
# 2985      7     1     154 -0.004382
# 2131      6     1       8 -0.006989
# 2885      7     1      54 -0.007730
#
#                                                   feats
# 4256  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# 3547  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# 4257  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# 2839  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# 3364  ['PSNR.csv_std', 'throughput_trace_kbps.csv_me...
# 2833  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# 3187  ['PSNR.csv_std', 'throughput_trace_kbps.csv_me...
# 2985  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# 2131  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# 2885  ['throughput_trace_kbps.csv_median', 'PSNR.csv...
# ******

# %%
from sklearn.ensemble import RandomForestRegressor
importance = get_feature_importance(depth = 9, n_tree = 1, max_leaf = 500, X_train = X_train, y_train = y_train)
feats = get_fewest_features(9, 1, 500, importance)[8]
model = RandomForestRegressor(max_depth=9, n_estimators = 1, max_leaf_nodes=500, n_jobs=4,
                                   random_state=42, bootstrap=False)
model.fit(X_train[feats], y_train2)
y_pred2 = model.predict(X_test[feats])

# %%
# RMSE
np.sqrt(np.mean((y_test2 - y_pred2) ** 2))
# Out:
# 0.15293341728365253

# %%
# Build dataframe to export
tmp = pd.DataFrame({'pred1' : y_pred, 'pred2' : y_pred2})
tmp.to_csv('/mnt/raid1/QoE_Data/LIVE_NFLX/data/preds.csv')
